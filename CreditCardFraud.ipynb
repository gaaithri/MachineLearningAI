# %% [markdown]
# <a href="https://colab.research.google.com/github/gaaithri/MachineLearningAI/blob/main/CreditCardFraud.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import gridspec

# %% [markdown]
# Step 1) Data cleaning and understanding

# %%
# Mounting of data

from google.colab import drive
drive.mount('/content/gdrive')
# cred_data = pd.read_csv
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# # New Section

# %%
cred_data = pd.read_csv("/content/gdrive/My Drive/creditcard.")

# %% [markdown]
# # New Section

# %% [markdown]
# # Look @Data

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
cred_data.head(7)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-903c26c0f376> in <module>()
# ----> 1 cred_data.head(7)
#
# NameError: name 'cred_data' is not defined

# %%
  cred_data.describe()

# %%
cred_data.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-cf064df33033> in <module>()
# ----> 1 cred_data.shape
#
# NameError: name 'cred_data' is not defined

# %%
data.info

# %%
Fraud = data[data["Class"] == 1]

# %%
Valid = data[data["Class"] == 0]

# %%
len(Fraud)

# %%
len(Valid)

# %%
Percent_Fraud = len(Fraud)/9965

# %%
Percent_Valid = len(Valid)/9965
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6717cd46272a> in <module>()
# ----> 1 Percent_Valid = len(Valid)/9965
#
# NameError: name 'Valid' is not defined

# %%
print("The Percentage of Transaction Wise:\nFraud:" ,round(Percent_Fraud,3) , "\nValid:" ,round(Percent_Valid,3))

# %% [markdown]
# # Data Cleaning
